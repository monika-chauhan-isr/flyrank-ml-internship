# %% [markdown]
# <a href="https://colab.research.google.com/github/monika-chauhan-isr/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/monika-chauhan-isr/flyrank-ml-intership/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My lane: Refresh / Content Opportunity Scoring
#
# I am choosing the Refresh / Content Opportunity Scoring lane. The goal is to identify which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring. This is useful because a review team has limited time and cannot manually inspect every page equally. I want to use observable search and content signals such as impressions, clicks, CTR, position, content age, and engagement to prioritize pages for human review. The goal is decision support rather than claiming that a model can guarantee which page will improve after a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The question: decision, action, cost of a wrong call
#
# The decision is which pages should be prioritized for review and possible content refresh. A content or SEO team would act on the recommendation by reviewing high-priority pages first and deciding whether to refresh, expand, protect, prune, or monitor them. A wrong recommendation could waste the team's limited time on a page that does not need attention, while a missed high-opportunity page could delay a useful improvement. The unit of analysis is an individual page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/monika-chauhan-isr/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of pages: 30000
# Average CTR: 0.5107
# Average impressions (90d): 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words: what I can and can't claim
#
# I can say that the dataset contains observable page-level signals such as impressions, clicks, CTR, position, content characteristics, and engagement-related measures. I can use these signals to identify patterns and prioritize pages for human review.
#
# I cannot claim that these signals prove why a page performs the way it does, guarantee that a refresh will improve performance, or predict Google's ranking decisions. The model should be treated as decision support for prioritization, not as proof of causation or a guarantee of future results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
